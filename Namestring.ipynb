# %%
name = "sagar chandrakant pujari"
print(len(name))
print(name[0])
print(name[-1])
print(name[22])
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])

a = name[0]
a1 = name[1]
a2 = name[2]
a3 = name[3]
a4 = name[4]
a5 = name[5]

print(a,a1,a2,a3,a4,a5)

az = name[6]
a0 = name[7]
a11 = name[8]
a21 = name[9]
a31 = name[10]
a41 = name[11]
a51 = name[12]
a00 = name[13]
a111 = name[14]
a211 = name[15]
a311 = name[16]
a411 = name[17]

print(az,a0,a11,a21,a31,a41,a51,a00,a111,a211,a311,a411)


b1 = name[-6]
b2 = name[-5]
b3 = name[-4]
b4 = name[-3]
b5 = name[-2]
b6 = name[-1]

print(b1,b2,b3,b4,b5,b6)

print(len(name)-1)

print(name[10-6])

print(name[10-10])

print(name[12+11])

print(name[9+9])

print(name[10*2])

print(name[10%2])
# Out:
# 24
# s
# i
# r
# s
# a
# g
# a
# r
#
# s a g a r
# c h a n d r a k a n t
# p u j a r i
# 23
# r
# s
# i
# p
# j
# s
